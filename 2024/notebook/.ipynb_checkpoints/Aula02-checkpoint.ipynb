# %% [markdown]
# # Aula 02
# Nesta aula veremos:
# * continuação dos tipos de variáveis
# * pacote numpy
# * pacote pandas
# * matplotlib - plotagem de figuras

# %% [markdown]
# ## Continuação tipos de variáveis

# %%
# Exemplo lista
a=[1,2,3,10,20,30]
print(a)

#Indexação da lista = a[0]=1
print(a[0])

#Acessando o último valor da lista 
print(a[-1])
# Out:
# [1, 2, 3, 10, 20, 30]
# 1
# 30

# %%
#Determinando o comprimento da lista

b = len(a)
print('O comprimento da lista é: ' + str(b))
# Out:
# O comprimento da lista é: 6

# %% [markdown]
# ## O pacote numpy
# https://numpy.org/
#
# Este pacote serve para operações matriciais e estatísticas básicas.

# %%
#Importando o numpy
import numpy as np

# %%
#Criando um número aleatório com numpy
c=np.random.rand(100)
print(c)
print(type(c))

#Acessando o último valor do array numpy
print(c[-1])

#Acessando os 10 primeiros valores
print('Os 10 primeiros valores da lista são '+ str(c[0:10]))

for ii in range (0,10):
        print(str(ii)+' '+str(c[ii]))

#O comprimento do numpy array - shape da matriz
print('O shape da matriz é:')
print(np.shape(c))
# Out:
# [0.92411491 0.97812184 0.20511842 0.13569382 0.37691725 0.96710139
#  0.78106337 0.48321729 0.20335001 0.95589412 0.25739126 0.91669667
#  0.4142069  0.68894038 0.33860727 0.44201706 0.36199777 0.16061006
#  0.77930447 0.63202898 0.3807976  0.06236201 0.028417   0.84142663
#  0.70696816 0.69633126 0.05677386 0.79593444 0.40905639 0.81913104
#  0.75882509 0.58574945 0.09728324 0.89779092 0.41355571 0.72038573
#  0.94844655 0.32472899 0.4402698  0.71598253 0.8891551  0.02561221
#  0.06891951 0.20790424 0.46932049 0.77596135 0.19599784 0.53333712
#  0.055487   0.90397192 0.81002259 0.3513149  0.65431157 0.96884639
#  0.79996669 0.90172965 0.1505464  0.34629967 0.64371235 0.56360643
#  0.17782622 0.5562008  0.89015847 0.89113344 0.38855058 0.12893425
#  0.54046767 0.11609538 0.04698192 0.92619714 0.12049379 0.37095206
#  0.89343226 0.14090325 0.0498811  0.56988781 0.25539508 0.99617699
#  0.26531389 0.85649541 0.63139287 0.40973068 0.93868517 0.31878315
#  0.16938171 0.15820953 0.04644235 0.93359735 0.93232131 0.84461098
#  0.41539013 0.03715006 0.75374738 0.22720649 0.88101436 0.53806128
#  0.2094967  0.99030496 0.3785536  0.94178757]
# <class 'numpy.ndarray'>
# 0.9417875731663252
# Os 10 primeiros valores da lista são [0.92411491 0.97812184 0.20511842 0.13569382 0.37691725 0.96710139
#  0.78106337 0.48321729 0.20335001 0.95589412]
# 0 0.9241149074201751
# 1 0.9781218399723034
# 2 0.20511842198268526
# 3 0.13569382496145832
# 4 0.3769172502097454
# 5 0.9671013913422273
# 6 0.7810633698773957
# 7 0.4832172933535397
# 8 0.20335001121160678
# 9 0.9558941162036035
# O shape da matriz é:
# (100,)

# %%
#Criando uma matriz numpy
d=np.random.rand(100,100)
print(d)
print('Qual é o shape/dimensão da matriz')
print(np.shape(d))

#Acessando a matriz numpy
#Linha 10 e coluna 10
print('Indexação numpy - matriz 2D')
print(d[10,10])
# Out:
# [[0.24005591 0.58414743 0.1989489  ... 0.38897864 0.17498321 0.26497245]
#  [0.07554195 0.87873775 0.23445694 ... 0.69286617 0.18782398 0.49721566]
#  [0.54904806 0.62851123 0.11257248 ... 0.21857874 0.03016027 0.74333414]
#  ...
#  [0.0485536  0.90264234 0.25498453 ... 0.08804623 0.26511612 0.10546279]
#  [0.41709343 0.78909248 0.29962759 ... 0.05555755 0.08772325 0.78432707]
#  [0.58545533 0.92046817 0.04368835 ... 0.76020372 0.89361104 0.49539915]]
# Qual é o shape/dimensão da matriz
# (100, 100)
# Indexação numpy - matriz 2D
# 0.8530343657964143

# %%
#Gerando uma matriz 3D
mat3D=np.random.rand(365,100,100)
print(np.shape(mat3D))
# Out:
# (365, 100, 100)

# %%
#Acessando todos os valores da primeira dimensão na célula 49,49

timeSeries=mat3D[:,49,49]
print(timeSeries)

#Acessando 10 primeiros valores da primeira dimensão na célula 49,49

timeSeries=mat3D[:10,49,49]
print(timeSeries)

#Acessando 10 últimos valores da primeira dimensão na célula 49,49

timeSeries=mat3D[-10:,49,49]
print(timeSeries)
# Out:
# [0.74807962 0.42903453 0.68772174 0.88354616 0.39147647 0.02180228
#  0.58673971 0.85685578 0.30242936 0.94118159 0.77767667 0.42582044
#  0.61325233 0.51549084 0.45171144 0.03908296 0.49134621 0.86692434
#  0.01144695 0.61818192 0.02738049 0.78532999 0.3100913  0.13189973
#  0.31277465 0.97451864 0.31104074 0.83516432 0.01113273 0.92947107
#  0.89855909 0.42027147 0.62242293 0.45298585 0.40007928 0.82810138
#  0.95500034 0.55717475 0.98608586 0.54152138 0.38498981 0.57958226
#  0.51407568 0.95422511 0.85372591 0.85641816 0.7590118  0.92057036
#  0.56428519 0.67820677 0.69542425 0.59212314 0.60085556 0.11732494
#  0.39463018 0.26793576 0.49402075 0.5960424  0.12140342 0.16944422
#  0.18739502 0.33990242 0.80983189 0.94231894 0.01080986 0.22571919
#  0.7987084  0.06092978 0.12538758 0.75222611 0.00862292 0.94128288
#  0.42643224 0.53689974 0.12975455 0.23775698 0.18384889 0.33645886
#  0.65413802 0.29279774 0.02135123 0.25355177 0.46384515 0.16609446
#  0.45208608 0.21802101 0.99323346 0.03673169 0.21963781 0.38226594
#  0.62547391 0.55871617 0.3579362  0.75825405 0.78155338 0.44042814
#  0.45740106 0.42415103 0.74132314 0.17313479 0.1541889  0.86400795
#  0.02162469 0.49477031 0.91926357 0.59111051 0.9739222  0.24929532
#  0.53085278 0.1640745  0.6487252  0.19989768 0.59017112 0.20660243
#  0.7041132  0.91263406 0.41721359 0.58652013 0.54493084 0.85151564
#  0.16056038 0.06912758 0.61458527 0.45732147 0.76105566 0.30478214
#  0.22058233 0.32829974 0.44818882 0.71500545 0.61749033 0.53565998
#  0.8811656  0.76732677 0.06616481 0.43480405 0.57268249 0.62841496
#  0.1188684  0.32081001 0.73275897 0.17736223 0.71965559 0.19899736
#  0.73059103 0.59641587 0.14690592 0.62286611 0.32260875 0.26864793
#  0.12851708 0.33338352 0.48973829 0.31869955 0.43377605 0.41770109
#  0.32271479 0.95803244 0.4889723  0.11141658 0.4917132  0.49078641
#  0.22884418 0.02056017 0.41081168 0.91779389 0.04499496 0.53325456
#  0.82756755 0.10121391 0.67278998 0.90550116 0.32091319 0.89281305
#  0.63960585 0.46191567 0.75553755 0.20396795 0.77604312 0.58806796
#  0.27047377 0.78564008 0.07545713 0.28961008 0.47104666 0.99303287
#  0.07968849 0.41139392 0.53182957 0.31911832 0.35665598 0.73115943
#  0.31734495 0.71962262 0.86137974 0.89730375 0.73546398 0.86038041
#  0.3079934  0.32298299 0.50644389 0.80134155 0.20060838 0.31802538
#  0.77953739 0.75885423 0.84017301 0.478202   0.57006489 0.99067143
#  0.32224784 0.27632891 0.79623556 0.09638661 0.16867485 0.07471839
#  0.80320146 0.27282555 0.99648927 0.27622477 0.22886926 0.30508336
#  0.16623678 0.44024544 0.64222989 0.85082059 0.86085885 0.86591307
#  0.54130114 0.98404882 0.61182191 0.76492837 0.10857355 0.81172031
#  0.99547433 0.07151582 0.11278557 0.08713718 0.58341715 0.45619869
#  0.21276496 0.49887352 0.24152547 0.19936485 0.01500283 0.53895381
#  0.60141599 0.52401928 0.72362023 0.91582626 0.35167254 0.48256835
#  0.77691072 0.64871009 0.44320003 0.13401669 0.77364429 0.49672742
#  0.9557944  0.07066113 0.44883105 0.17780828 0.49475201 0.99181926
#  0.58924788 0.0153283  0.14698751 0.38296483 0.59289399 0.43174413
#  0.54867557 0.63026971 0.55618051 0.3891066  0.32790152 0.33425545
#  0.09518311 0.18011889 0.80835472 0.04552575 0.8653308  0.45650306
#  0.8831921  0.42725828 0.20480695 0.82650569 0.4038238  0.89608104
#  0.12621525 0.83690571 0.50928913 0.70989871 0.50637509 0.12002721
#  0.71119628 0.51074655 0.53686892 0.34647063 0.31100684 0.16157716
#  0.78361736 0.57296955 0.09689021 0.19014357 0.54212984 0.1600074
#  0.94395785 0.18148734 0.21430163 0.77865803 0.2837381  0.39795051
#  0.48501825 0.13458581 0.50147776 0.59516221 0.94970361 0.66739227
#  0.43158456 0.20679806 0.97034251 0.39274106 0.5849703  0.63715241
#  0.07105341 0.88526584 0.63459383 0.41447009 0.55838535 0.31472418
#  0.25861392 0.9049944  0.18995844 0.72528525 0.36724013 0.07465251
#  0.695341   0.77878595 0.61374173 0.12347913 0.04747803 0.39825047
#  0.59064114 0.25700957 0.39445147 0.86599013 0.94678576 0.04335461
#  0.59910513 0.17778263 0.12077741 0.35195784 0.04301772 0.5956201
#  0.4401765  0.99488401 0.75788642 0.38005772 0.87939252 0.39229581
#  0.81103511 0.6310809  0.23682314 0.69668415 0.37410861]
# [0.74807962 0.42903453 0.68772174 0.88354616 0.39147647 0.02180228
#  0.58673971 0.85685578 0.30242936 0.94118159]
# [0.99488401 0.75788642 0.38005772 0.87939252 0.39229581 0.81103511
#  0.6310809  0.23682314 0.69668415 0.37410861]

# %%
# Operções matriciais com numpy
timeSeries2=mat3D[:,50:52,50]
print(np.shape(timeSeries2))
print(timeSeries2.shape)

#Matriz transposta
timeSeriesTransposta = timeSeries2.transpose()
print(timeSeriesTransposta.shape)
# Out:
# (365, 2)
# (365, 2)
# (2, 365)

# %%
# Estatísticas com numpy

mediaTimeSeries=np.mean(timeSeries2)
print(mediaTimeSeries)

#Média nas colunas
print('Essa é a média de cada coluna')
mediaTScolumns=np.mean(timeSeries2,axis=0)
print(mediaTScolumns)

# Média nas linhas
print('Essa é a média de cada linha')
mediaTSrows=np.mean(timeSeries2,axis=1)
print(mediaTSrows.shape)

#Média na terceira dimensão
media3D=np.mean(mat3D,axis=0)
print(media3D.shape)
# Out:
# 0.5066697483902723
# Essa é a média de cada coluna
# [0.52219808 0.49114142]
# Essa é a média de cada linha
# (365,)
# (100, 100)

# %%
#Média, mínimo, máximo, desvio, percentil, mediana, variancia

#Média
media3D=np.mean(mat3D)
print(media3D)

#Mínimo
min3D=np.min(mat3D)
print(min3D)

#Máximo
max3D=np.max(mat3D)
print(max3D)

#Desvio
std3D=np.std(mat3D)
print(std3D)

#Percentil
perc3D=np.percentile(mat3D,90)
print(perc3D)

#Mediana
median3D=np.median(mat3D)
print(median3D)

#variância
var3D=std3D**2
print(var3D)

var3D=np.var(mat3D)
print(var3D)
# Out:
# 0.5001721917776408
# 2.519374111553674e-07
# 0.9999999748437666
# 0.28877175235832425
# 0.9002452095510912
# 0.5003570347960691
# 0.08338912496009734
# 0.08338912496009734

# %%
#Concatenação
mat3D2=mat3D.copy()
matConcat=np.concatenate([mat3D,mat3D2])
print(matConcat.shape)
# Out:
# (730, 100, 100)

# %%
#Concatenação em list
listMat=[mat3D,mat3D,mat3D]
mat3Dconc=np.concatenate(listMat)
print(mat3Dconc.shape)
# Out:
# (1095, 100, 100)

# %% [markdown]
# ## Plotando com o matplotlib
# https://matplotlib.org/
# * plot
# * histogram
# * bar
# * boxplot
# * pcolor

# %%
#Importando o pacote matplotlib
import matplotlib.pyplot as plt

#Criando um objeto matplotlib para plotar as figuras
fig,ax=plt.subplots(3)

#lineplot
ax[0].plot(mat3D[:,10,10])
ax[1].plot(mat3D[:,10:12,10])

#bar
ax[2].bar(np.array(range(0,mat3D.shape[0])),mat3D[:,10,10])
print(type(range(0,mat3D.shape[0])))
# Out:
# <class 'range'>

# %%
#BOXPLOT
fig,ax=plt.subplots()
ax.boxplot(mat3D[:,10:20,0])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dbb10972d0>,
#   <matplotlib.lines.Line2D at 0x1dbb1097c50>,
#   <matplotlib.lines.Line2D at 0x1dbb10a6cd0>,
#   <matplotlib.lines.Line2D at 0x1dbb10a74d0>,
#   <matplotlib.lines.Line2D at 0x1dbb10ba7d0>,
#   <matplotlib.lines.Line2D at 0x1dbb10bb050>,
#   <matplotlib.lines.Line2D at 0x1dbb10c6150>,
#   <matplotlib.lines.Line2D at 0x1dbb10c6a10>,
#   <matplotlib.lines.Line2D at 0x1dbb10d5c90>,
#   <matplotlib.lines.Line2D at 0x1dbb10d64d0>,
#   <matplotlib.lines.Line2D at 0x1dbb0eb55d0>,
#   <matplotlib.lines.Line2D at 0x1dbb0eb5dd0>,
#   <matplotlib.lines.Line2D at 0x1dbb0ec0e90>,
#   <matplotlib.lines.Line2D at 0x1dbb0ec16d0>,
#   <matplotlib.lines.Line2D at 0x1dbb0ed0850>,
#   <matplotlib.lines.Line2D at 0x1dbb0ed1150>,
#   <matplotlib.lines.Line2D at 0x1dbb0ee42d0>,
#   <matplotlib.lines.Line2D at 0x1dbb0ee4a90>,
#   <matplotlib.lines.Line2D at 0x1dbb0ee7450>,
#   <matplotlib.lines.Line2D at 0x1dbb0ee7bd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1dbb10a4550>,
#   <matplotlib.lines.Line2D at 0x1dbb10a4dd0>,
#   <matplotlib.lines.Line2D at 0x1dbb10a7dd0>,
#   <matplotlib.lines.Line2D at 0x1dbb10b8690>,
#   <matplotlib.lines.Line2D at 0x1dbb10bb910>,
#   <matplotlib.lines.Line2D at 0x1dbb10c4250>,
#   <matplotlib.lines.Line2D at 0x1dbb10c7210>,
#   <matplotlib.lines.Line2D at 0x1dbb10c7b10>,
#   <matplotlib.lines.Line2D at 0x1dbb10d6c90>,
#   <matplotlib.lines.Line2D at 0x1dbb10d7490>,
#   <matplotlib.lines.Line2D at 0x1dbb0eb6650>,
#   <matplotlib.lines.Line2D at 0x1dbb0eb6e50>,
#   <matplotlib.lines.Line2D at 0x1dbb0ec1f10>,
#   <matplotlib.lines.Line2D at 0x1dbb0ec2750>,
#   <matplotlib.lines.Line2D at 0x1dbb0ed19d0>,
#   <matplotlib.lines.Line2D at 0x1dbb0ed2250>,
#   <matplotlib.lines.Line2D at 0x1dbb0ee5250>,
#   <matplotlib.lines.Line2D at 0x1dbb108bad0>,
#   <matplotlib.lines.Line2D at 0x1dbb0ef4390>,
#   <matplotlib.lines.Line2D at 0x1dbb0ef4b50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1dbb103a550>,
#   <matplotlib.lines.Line2D at 0x1dbb10a6450>,
#   <matplotlib.lines.Line2D at 0x1dbb10ba010>,
#   <matplotlib.lines.Line2D at 0x1dbb10c5a10>,
#   <matplotlib.lines.Line2D at 0x1dbb10d5490>,
#   <matplotlib.lines.Line2D at 0x1dbb0eb4e10>,
#   <matplotlib.lines.Line2D at 0x1dbb0ec0710>,
#   <matplotlib.lines.Line2D at 0x1dbb0ed0110>,
#   <matplotlib.lines.Line2D at 0x1dbb0ed3b10>,
#   <matplotlib.lines.Line2D at 0x1dbb0ee6d10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dbb10a56d0>,
#   <matplotlib.lines.Line2D at 0x1dbb10b8ed0>,
#   <matplotlib.lines.Line2D at 0x1dbb10c4950>,
#   <matplotlib.lines.Line2D at 0x1dbb10d4450>,
#   <matplotlib.lines.Line2D at 0x1dbb10d7cd0>,
#   <matplotlib.lines.Line2D at 0x1dbb0eb7710>,
#   <matplotlib.lines.Line2D at 0x1dbb0ec2fd0>,
#   <matplotlib.lines.Line2D at 0x1dbb0ed29d0>,
#   <matplotlib.lines.Line2D at 0x1dbb0ee5b90>,
#   <matplotlib.lines.Line2D at 0x1dbb0ef5350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dbb10a5e10>,
#   <matplotlib.lines.Line2D at 0x1dbb10b9710>,
#   <matplotlib.lines.Line2D at 0x1dbb10c5110>,
#   <matplotlib.lines.Line2D at 0x1dbb10d4bd0>,
#   <matplotlib.lines.Line2D at 0x1dbb0eb4550>,
#   <matplotlib.lines.Line2D at 0x1dbb0eb7e50>,
#   <matplotlib.lines.Line2D at 0x1dbb0ec3850>,
#   <matplotlib.lines.Line2D at 0x1dbb0ed3250>,
#   <matplotlib.lines.Line2D at 0x1dbb0ee6490>,
#   <matplotlib.lines.Line2D at 0x1dbb0ef5ad0>],
#  'means': []}

# %%
#pcolor-gráfico de superfície
fig,ax=plt.subplots(2,2)
ax[0,0].pcolor(mat3D[0,:,:],cmap='gray')
ax[0,1].contour(np.sin(mat3D[0,:,:]))

# %% [markdown]
# ## Utilizando o Pandas
# https://pandas.pydata.org/

# %%
import pandas as pd

# %%
df = pd.read_csv('87317030_Vazoes_treated.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = pd.read_csv('87317030_Vazoes_treated.csv')
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '87317030_Vazoes_treated.csv'

# %%
#Plotando com dataframe
fig,ax=plt.subplots(4)
df['temp'].plot(ax=ax[0])

# %%
#a partir daqui me perdi total na aula
#sor usou o pip install wind rose, pra instalar uma outra biblioteca
